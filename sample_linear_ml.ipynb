# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# Read the CSV file into a pandas DataFrame
spotify_df = pd.read_csv('sample_data.csv')
spotify_df.head()
# Out:
#        Country                                                Uri  Popularity  \
# 0  New Zealand  https://open.spotify.com/track/5v7h5vQgCJKZT5v...    68931.10
# 1      Finland  https://open.spotify.com/track/1z4jCtA9thODROr...    68943.35
# 2       France  https://open.spotify.com/track/7gXWIxX7rUtKGNt...     4980.00
# 3       France  https://open.spotify.com/track/6sO5rB2K8fIJVt1...     4190.80
# 4      Austria  https://open.spotify.com/track/40WQl2fD6jTAV2z...      114.75
#
#              Title         Artist  Album/Single              Genre  \
# 0       in the air         L.A.B.             0          nz reggae
# 1    japanese drip  Kube - Cledos             0  finnish dance pop
# 2          mamamia          RIDSA             0          francoton
# 3            amigo            Jul             0          francoton
# 4  sie will zu mir      Yung Hurn             0     german hip hop
#
#    Artist_followers  Explicit                    Album  ... speechiness  \
# ...

# %%
# Assign the data to X and y\
y = spotify_df["Artist_followers"]
X = spotify_df[['danceability', 'energy', 'key', 'speechiness', 'acoustics', 'instrumentalness', 'liveliness', 'valence']].copy()

# %%
# Use train_test_split to create training and testing data.

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model by using LinearRegression.

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data, and calculate the scores for the training and testing data.

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.2366776610732676
# Testing Score: 0.22802485411053242

# %%
# Plot the residuals for the training and testing data.

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION
